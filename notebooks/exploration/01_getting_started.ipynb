# %% [markdown]
# # F1 Analysis — Getting Started
#
# Quick exploration of FastF1 sessions via the project helpers.

# %%
import sys
sys.path.insert(0, '../..')

from src.f1_utils import get_event_schedule, load_session, compare_drivers_fastest, tyre_strategy

schedule = get_event_schedule(2024)
schedule.head(10)

# %%
# Load a session (first download will hit the FastF1 cache)
session = load_session(2024, 'Monaco', 'Q')
print(session)

# %%
drivers = ['VER', 'LEC', 'SAI', 'NOR', 'HAM']
compare_drivers_fastest(session, drivers)

# %%
tyre_strategy(session, drivers)
